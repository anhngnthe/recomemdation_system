# %%
import numpy as np
import pandas as pd
import warnings
from sklearn.metrics.pairwise import cosine_similarity
warnings.filterwarnings('ignore')

# %%
anime = pd.read_csv("D:/code/anime.csv")
anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
print(anime.shape)
# anime = anime[(anime['type'] == 'TV') | (anime['type'] == 'Movie')]
print(anime.shape)
# Out:
# (12294, 7)
# (12294, 7)

# %%
# only select famous anime, 75% percentile
m = anime['members'].quantile(0.75)
anime = anime[(anime['members'] >= m)]
anime.shape
# Out:
# (3074, 7)

# %%
rating = pd.read_csv("D:/code/rating.csv")
rating.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %%
rating.shape
# Out:
# (7813737, 3)

# %%
rating.loc[rating.rating == -1, 'rating'] = np.NaN
rating.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20     NaN
# 1        1        24     NaN
# 2        1        79     NaN
# 3        1       226     NaN
# 4        1       241     NaN

# %%
anime_index = pd.Series(anime.index, index=anime.name)
anime_index.head()
# Out:
# name
# Kimi no Na wa.                      0
# Fullmetal Alchemist: Brotherhood    1
# Gintama°                            2
# Steins;Gate                         3
# Gintama&#039;                       4
# dtype: int64

# %%
joined = anime.merge(rating, how='inner', on='anime_id')
joined.head()
# Out:
#    anime_id            name                                 genre   type  \
# 0     32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
# 1     32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
# 2     32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
# 3     32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
# 4     32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
#
#   episodes  rating_x  members  user_id  rating_y
# 0        1      9.37   200630       99       5.0
# 1        1      9.37   200630      152      10.0
# 2        1      9.37   200630      244      10.0
# 3        1      9.37   200630      271      10.0
# 4        1      9.37   200630      278       NaN

# %%
joined = joined[['user_id', 'name', 'rating_y']]

pivot = pd.pivot_table(joined, index='name', columns='user_id', values='rating_y')
pivot.head()
# Out:
# user_id                                             1      2      3      \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN    NaN    NaN
# .hack//G.U. Returner                                  NaN    NaN    NaN
# .hack//G.U. Trilogy                                   NaN    NaN    NaN
#
# user_id                                             5      7      8      \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN    NaN    NaN
# .hack//G.U. Returner                                  NaN    NaN    NaN
# .hack//G.U. Trilogy                                   NaN    NaN    NaN
#
# user_id                                             9      10     11     \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN    NaN    NaN
# .hack//G.U. Returner                                  NaN    NaN    NaN
# .hack//G.U. Trilogy                                   NaN    NaN    NaN
#
# user_id                                             12     ...  73507  73508  \
# name                                                       ...
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN  ...    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN  ...    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN  ...    NaN    NaN
# .hack//G.U. Returner                                  NaN  ...    NaN    NaN
# .hack//G.U. Trilogy                                   NaN  ...    NaN    NaN
#
# user_id                                             73509  73510  73511  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN    6.0    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN    NaN    NaN
# .hack//G.U. Returner                                  NaN    NaN    NaN
# .hack//G.U. Trilogy                                   NaN    NaN    NaN
#
# user_id                                             73512  73513  73514  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN    NaN    NaN
# .hack//G.U. Returner                                  NaN    NaN    NaN
# .hack//G.U. Trilogy                                   NaN    NaN    NaN
#
# user_id                                             73515  73516
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN    NaN
# .hack//G.U. Returner                                  NaN    NaN
# .hack//G.U. Trilogy                                   NaN    NaN
#
# [5 rows x 69500 columns]

# %%
pivot.shape
# Out:
# (2968, 69500)

# %%
pivot.dropna(axis=1, how='all', inplace=True)
pivot.head()
# Out:
# user_id                                             1      2      3      \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN    NaN    NaN
# .hack//G.U. Returner                                  NaN    NaN    NaN
# .hack//G.U. Trilogy                                   NaN    NaN    NaN
#
# user_id                                             5      7      8      \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN    NaN    NaN
# .hack//G.U. Returner                                  NaN    NaN    NaN
# .hack//G.U. Trilogy                                   NaN    NaN    NaN
#
# user_id                                             9      10     11     \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN    NaN    NaN
# .hack//G.U. Returner                                  NaN    NaN    NaN
# .hack//G.U. Trilogy                                   NaN    NaN    NaN
#
# user_id                                             12     ...  73507  73508  \
# name                                                       ...
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN  ...    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN  ...    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN  ...    NaN    NaN
# .hack//G.U. Returner                                  NaN  ...    NaN    NaN
# .hack//G.U. Trilogy                                   NaN  ...    NaN    NaN
#
# user_id                                             73509  73510  73511  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN    6.0    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN    NaN    NaN
# .hack//G.U. Returner                                  NaN    NaN    NaN
# .hack//G.U. Trilogy                                   NaN    NaN    NaN
#
# user_id                                             73512  73513  73514  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN    NaN    NaN
# .hack//G.U. Returner                                  NaN    NaN    NaN
# .hack//G.U. Trilogy                                   NaN    NaN    NaN
#
# user_id                                             73515  73516
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN    NaN
# .hack//G.U. Returner                                  NaN    NaN
# .hack//G.U. Trilogy                                   NaN    NaN
#
# [5 rows x 69500 columns]

# %%
pivot.shape
# Out:
# (2968, 69500)

# %%
pivot_norm = pivot.apply(lambda x: x - np.nanmean(x), axis=1)
pivot_norm.head()
# Out:
# user_id                                             1      2      3      \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN    NaN    NaN
# .hack//G.U. Returner                                  NaN    NaN    NaN
# .hack//G.U. Trilogy                                   NaN    NaN    NaN
#
# user_id                                             5      7      8      \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN    NaN    NaN
# .hack//G.U. Returner                                  NaN    NaN    NaN
# .hack//G.U. Trilogy                                   NaN    NaN    NaN
#
# user_id                                             9      10     11     \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN    NaN    NaN
# .hack//G.U. Returner                                  NaN    NaN    NaN
# .hack//G.U. Trilogy                                   NaN    NaN    NaN
#
# user_id                                             12     ...  73507  73508  \
# name                                                       ...
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN  ...    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN  ...    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN  ...    NaN    NaN
# .hack//G.U. Returner                                  NaN  ...    NaN    NaN
# .hack//G.U. Trilogy                                   NaN  ...    NaN    NaN
#
# user_id                                             73509     73510  73511  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN       NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN -1.744713    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN       NaN    NaN
# .hack//G.U. Returner                                  NaN       NaN    NaN
# .hack//G.U. Trilogy                                   NaN       NaN    NaN
#
# user_id                                             73512  73513  73514  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN    NaN    NaN
# .hack//G.U. Returner                                  NaN    NaN    NaN
# .hack//G.U. Trilogy                                   NaN    NaN    NaN
#
# user_id                                             73515  73516
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    NaN    NaN
# &quot;Bungaku Shoujo&quot; Memoire                    NaN    NaN
# &quot;Bungaku Shoujo&quot; Movie                      NaN    NaN
# .hack//G.U. Returner                                  NaN    NaN
# .hack//G.U. Trilogy                                   NaN    NaN
#
# [5 rows x 69500 columns]

# %%
# fill NaN with 0
pivot_norm.fillna(0, inplace=True)
pivot_norm.head()
# Out:
# user_id                                             1      2      3      \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0    0.0
# .hack//G.U. Returner                                  0.0    0.0    0.0
# .hack//G.U. Trilogy                                   0.0    0.0    0.0
#
# user_id                                             5      7      8      \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0    0.0
# .hack//G.U. Returner                                  0.0    0.0    0.0
# .hack//G.U. Trilogy                                   0.0    0.0    0.0
#
# user_id                                             9      10     11     \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0    0.0
# .hack//G.U. Returner                                  0.0    0.0    0.0
# .hack//G.U. Trilogy                                   0.0    0.0    0.0
#
# user_id                                             12     ...  73507  73508  \
# name                                                       ...
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0  ...    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0  ...    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0  ...    0.0    0.0
# .hack//G.U. Returner                                  0.0  ...    0.0    0.0
# .hack//G.U. Trilogy                                   0.0  ...    0.0    0.0
#
# user_id                                             73509     73510  73511  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0  0.000000    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0 -1.744713    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0  0.000000    0.0
# .hack//G.U. Returner                                  0.0  0.000000    0.0
# .hack//G.U. Trilogy                                   0.0  0.000000    0.0
#
# user_id                                             73512  73513  73514  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0    0.0
# .hack//G.U. Returner                                  0.0    0.0    0.0
# .hack//G.U. Trilogy                                   0.0    0.0    0.0
#
# user_id                                             73515  73516
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0
# .hack//G.U. Returner                                  0.0    0.0
# .hack//G.U. Trilogy                                   0.0    0.0
#
# [5 rows x 69500 columns]

# %%
# convert into dataframe to make it easier
item_sim_df = pd.DataFrame(cosine_similarity(pivot_norm, pivot_norm), index=pivot_norm.index, columns=pivot_norm.index)
item_sim_df.head()
# Out:
# name                                                &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                           1.000000
# &quot;Bungaku Shoujo&quot; Memoire                                                           0.476263
# &quot;Bungaku Shoujo&quot; Movie                                                             0.299126
# .hack//G.U. Returner                                                                         0.043865
# .hack//G.U. Trilogy                                                                          0.042919
#
# name                                                &quot;Bungaku Shoujo&quot; Memoire  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                            0.476263
# &quot;Bungaku Shoujo&quot; Memoire                                            1.000000
# &quot;Bungaku Shoujo&quot; Movie                                              0.389786
# .hack//G.U. Returner                                                          0.055426
# .hack//G.U. Trilogy                                                           0.044266
#
# name                                                &quot;Bungaku Shoujo&quot; Movie  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                          0.299126
# &quot;Bungaku Shoujo&quot; Memoire                                          0.389786
# &quot;Bungaku Shoujo&quot; Movie                                            1.000000
# .hack//G.U. Returner                                                        0.027617
# .hack//G.U. Trilogy                                                         0.029818
#
# name                                                .hack//G.U. Returner  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...              0.043865
# &quot;Bungaku Shoujo&quot; Memoire                              0.055426
# &quot;Bungaku Shoujo&quot; Movie                                0.027617
# .hack//G.U. Returner                                            1.000000
# .hack//G.U. Trilogy                                             0.415618
#
# name                                                .hack//G.U. Trilogy  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...             0.042919
# &quot;Bungaku Shoujo&quot; Memoire                             0.044266
# &quot;Bungaku Shoujo&quot; Movie                               0.029818
# .hack//G.U. Returner                                           0.415618
# .hack//G.U. Trilogy                                            1.000000
#
# name                                                .hack//Gift  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...     0.051351
# &quot;Bungaku Shoujo&quot; Memoire                     0.039442
# &quot;Bungaku Shoujo&quot; Movie                       0.026062
# .hack//G.U. Returner                                   0.294378
# .hack//G.U. Trilogy                                    0.221281
#
# name                                                .hack//Intermezzo  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           0.050538
# &quot;Bungaku Shoujo&quot; Memoire                           0.052593
# &quot;Bungaku Shoujo&quot; Movie                             0.031229
# .hack//G.U. Returner                                         0.316503
# .hack//G.U. Trilogy                                          0.217601
#
# name                                                .hack//Liminality  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           0.044302
# &quot;Bungaku Shoujo&quot; Memoire                           0.068060
# &quot;Bungaku Shoujo&quot; Movie                             0.047449
# .hack//G.U. Returner                                         0.248595
# .hack//G.U. Trilogy                                          0.205317
#
# name                                                .hack//Quantum  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...        0.042532
# &quot;Bungaku Shoujo&quot; Memoire                        0.042553
# &quot;Bungaku Shoujo&quot; Movie                          0.041878
# .hack//G.U. Returner                                      0.184046
# .hack//G.U. Trilogy                                       0.180574
#
# name                                                .hack//Roots  ...  \
# name                                                              ...
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.033241  ...
# &quot;Bungaku Shoujo&quot; Memoire                      0.026746  ...
# &quot;Bungaku Shoujo&quot; Movie                        0.032753  ...
# .hack//G.U. Returner                                    0.299592  ...
# .hack//G.U. Trilogy                                     0.292491  ...
#
# name                                                ef: A Tale of Melodies. - Prologue  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                            0.060334
# &quot;Bungaku Shoujo&quot; Memoire                                            0.046152
# &quot;Bungaku Shoujo&quot; Movie                                              0.041890
# .hack//G.U. Returner                                                          0.032874
# .hack//G.U. Trilogy                                                           0.018953
#
# name                                                ef: A Tale of Memories.  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                 0.051792
# &quot;Bungaku Shoujo&quot; Memoire                                 0.055558
# &quot;Bungaku Shoujo&quot; Movie                                   0.079183
# .hack//G.U. Returner                                               0.032198
# .hack//G.U. Trilogy                                                0.047082
#
# name                                                ef: A Tale of Memories. - Prologue  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                            0.068119
# &quot;Bungaku Shoujo&quot; Memoire                                            0.041248
# &quot;Bungaku Shoujo&quot; Movie                                              0.035454
# .hack//G.U. Returner                                                          0.018648
# .hack//G.U. Trilogy                                                           0.025093
#
# name                                                iDOLM@STER Xenoglossia  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                0.034533
# &quot;Bungaku Shoujo&quot; Memoire                                0.040169
# &quot;Bungaku Shoujo&quot; Movie                                  0.038790
# .hack//G.U. Returner                                              0.039393
# .hack//G.U. Trilogy                                               0.031165
#
# name                                                s.CRY.ed  xxxHOLiC  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...  0.004571  0.048129
# &quot;Bungaku Shoujo&quot; Memoire                  0.004316  0.042755
# &quot;Bungaku Shoujo&quot; Movie                    0.008384  0.035791
# .hack//G.U. Returner                                0.028894  0.026371
# .hack//G.U. Trilogy                                 0.043349  0.027536
#
# name                                                xxxHOLiC Kei  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.062349
# &quot;Bungaku Shoujo&quot; Memoire                      0.053983
# &quot;Bungaku Shoujo&quot; Movie                        0.049389
# .hack//G.U. Returner                                    0.032321
# .hack//G.U. Trilogy                                     0.034512
#
# name                                                xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                 0.066395
# &quot;Bungaku Shoujo&quot; Memoire                                                 0.052674
# &quot;Bungaku Shoujo&quot; Movie                                                   0.047023
# .hack//G.U. Returner                                                               0.036948
# .hack//G.U. Trilogy                                                                0.034838
#
# name                                                xxxHOLiC Rou  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.056868
# &quot;Bungaku Shoujo&quot; Memoire                      0.053376
# &quot;Bungaku Shoujo&quot; Movie                        0.054956
# .hack//G.U. Returner                                    0.026925
# .hack//G.U. Trilogy                                     0.024894
#
# name                                                xxxHOLiC Shunmuki
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           0.071502
# &quot;Bungaku Shoujo&quot; Memoire                           0.060179
# &quot;Bungaku Shoujo&quot; Movie                             0.049362
# .hack//G.U. Returner                                         0.023736
# .hack//G.U. Trilogy                                          0.020009
#
# [5 rows x 2968 columns]

# %%
def get_similar_anime(anime_name):
    if anime_name not in pivot_norm.index:
        return None, None
    else:
        sim_animes = item_sim_df.sort_values(by=anime_name, ascending=False).index[1:]
        sim_score = item_sim_df.sort_values(by=anime_name, ascending=False).loc[:, anime_name].tolist()[1:]
        return sim_animes, sim_score
    
animes, score = get_similar_anime("Steins;Gate")
for x,y in zip(animes[:10], score[:10]):
    print("{} with similarity of {}".format(x, y))
# Out:
# Steins;Gate: Oukoubakko no Poriomania with similarity of 0.310653320349011
# Steins;Gate Movie: Fuka Ryouiki no Déjà vu with similarity of 0.24336781483926156
# Psycho-Pass with similarity of 0.1841425084628399
# Code Geass: Hangyaku no Lelouch R2 with similarity of 0.18246014048789994
# Fate/Zero 2nd Season with similarity of 0.18113560310021667
# Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai. with similarity of 0.17588179421245187
# Fate/Zero with similarity of 0.17547220214978015
# Fullmetal Alchemist: Brotherhood with similarity of 0.16823351950204468
# Code Geass: Hangyaku no Lelouch with similarity of 0.16785600931464761
# Angel Beats! with similarity of 0.16348349134494158

# %%
# predict the rating of anime x by user y
def predict_rating(user_id, anime_name, max_neighbor=10):
    animes, scores = get_similar_anime(anime_name)
    anime_arr = np.array([x for x in animes])
    sim_arr = np.array([x for x in scores])
    
    # select only the anime that has already rated by user x
    filtering = pivot_norm[user_id].loc[anime_arr] != 0
    
    # calculate the predicted score
    s = np.dot(sim_arr[filtering][:max_neighbor], pivot[user_id].loc[anime_arr[filtering][:max_neighbor]]) \
            / np.sum(sim_arr[filtering][:max_neighbor])
    
    return s

# %%
predict_rating(3, "Steins;Gate")
# Out:
# 9.0511507264121

# %%
predict_rating(3, "Matrix")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16572\286068923.py in <module>
# ----> 1 predict_rating(3, "Matrix")
#
# NameError: name 'predict_rating' is not defined

# %%
# recommend top n_anime for user x based on item collaborative filtering algorithm
def get_recommendation(user_id, n_anime=10):
    predicted_rating = np.array([])
    
    for _anime in pivot_norm.index:
        predicted_rating = np.append(predicted_rating, predict_rating(user_id, _anime))
    
    # don't recommend something that user has already rated
    temp = pd.DataFrame({'predicted':predicted_rating, 'name':pivot_norm.index})
    filtering = (pivot_norm[user_id] == 0.0)
    temp = temp.loc[filtering.values].sort_values(by='predicted', ascending=False)

    # recommend n_anime anime
    return anime.loc[anime_index.loc[temp.name[:n_anime]]]

# %%
get_recommendation(3)
# Out:
#      anime_id                            name  \
# 32       5258  Hajime no Ippo: New Challenger
# 6       11061          Hunter x Hunter (2011)
# 44      19647          Hajime no Ippo: Rising
# 4        9969                   Gintama&#039;
# 108      7655                        Major S6
# 12        918                         Gintama
# 20        263                  Hajime no Ippo
# 39      12365             Bakuman. 3rd Season
# 405      2159              Ookiku Furikabutte
# 139       627                        Major S1
#
#                                                  genre type episodes  rating  \
# 32                      Comedy, Drama, Shounen, Sports   TV       26    8.75
# 6              Action, Adventure, Shounen, Super Power   TV      148    9.13
# 44                      Comedy, Drama, Shounen, Sports   TV       25    8.68
# 4    Action, Comedy, Historical, Parody, Samurai, S...   TV       51    9.16
# 108                              Comedy, Drama, Sports   TV       25    8.49
# 12   Action, Comedy, Historical, Parody, Samurai, S...   TV      201    9.04
# 20                      Comedy, Drama, Shounen, Sports   TV       75    8.83
# 39                     Comedy, Drama, Romance, Shounen   TV       25    8.71
# 405                                     Comedy, Sports   TV       25    8.11
# 139                     Comedy, Drama, Shounen, Sports   TV       26    8.42
#
#      members
# 32     88995
# 6     425855
# 44     66756
# 4     151266
# 108    24788
# 12    336376
# 20    157670
# 39    133620
# 405    49599
# 139    41061

# %%
get_recommendation(1)
# Out:
#       anime_id                                               name  \
# 501       4163                               Seto no Hanayome OVA
# 3961       447                                         Weiß Kreuz
# 2515      6151  Final Fantasy VII: On the Way to a Smile - Epi...
# 183       9863                                         SKET Dance
# 3796     19109            Fate/kaleid liner Prisma☆Illya Specials
# 4109     18851  Fate/kaleid liner Prisma☆Illya: Undoukai de Da...
# 1339      6922       Fate/stay night Movie: Unlimited Blade Works
# 3331      7559                    Fate/stay night TV Reproduction
# 127      28701  Fate/stay night: Unlimited Blade Works 2nd Season
# 1785     31389  Fate/stay night: Unlimited Blade Works 2nd Sea...
#
#                                                   genre     type episodes  \
# 501                     Comedy, Parody, Romance, School      OVA        2
# 3961                             Action, Drama, Shounen       TV       25
# 2515                       Action, Fantasy, Super Power      OVA        1
# 183                             Comedy, School, Shounen       TV       77
# 3796                      Comedy, Ecchi, Fantasy, Magic  Special        5
# 4109                             Comedy, Fantasy, Magic      OVA        1
# 1339               Action, Fantasy, Magic, Supernatural    Movie        1
# 3331  Action, Fantasy, Magic, Romance, Shounen, Supe...      OVA        2
# 127       Action, Fantasy, Magic, Shounen, Supernatural       TV       13
# 1785      Action, Fantasy, Magic, Shounen, Supernatural  Special        1
#
#       rating  members
# 501     8.03    31973
# 3961    6.84    13039
# 2515    7.24    18795
# 183     8.36   101027
# 3796    6.88    16886
# 4109    6.80    22543
# 1339    7.58   110983
# 3331    7.02    23498
# 127     8.45   205987
# 1785    7.44    26382

# %%
get_recommendation(7)
# Out:
#      anime_id                                               name  \
# 336       731  Interstella5555: The 5tory of The 5ecret 5tar ...
# 358        47                                              Akira
# 817       474                                       Macross Plus
# 731        91             Mobile Suit Gundam Wing: Endless Waltz
# 71        578                                     Hotaru no Haka
# 726       570                                            Jin-Rou
# 384        81               Mobile Suit Gundam: The 08th MS Team
# 624       468                    Ghost in the Shell 2: Innocence
# 152         5                    Cowboy Bebop: Tengoku no Tobira
# 614      2273       Mobile Suit Gundam Wing: Endless Waltz Movie
#
#                                                  genre   type episodes  \
# 336                    Adventure, Drama, Music, Sci-Fi  Music        1
# 358  Action, Adventure, Horror, Military, Sci-Fi, S...  Movie        1
# 817     Drama, Mecha, Military, Romance, Sci-Fi, Space    OVA        4
# 731      Action, Drama, Mecha, Military, Sci-Fi, Space    OVA        3
# 71                                   Drama, Historical  Movie        1
# 726    Drama, Military, Police, Psychological, Romance  Movie        1
# 384  Adventure, Drama, Mecha, Military, Romance, Sc...    OVA       12
# 624     Mecha, Military, Police, Psychological, Sci-Fi  Movie        1
# 152              Action, Drama, Mystery, Sci-Fi, Space  Movie        1
# 614      Action, Drama, Mecha, Military, Sci-Fi, Space  Movie        1
#
#      rating  members
# 336    8.17    31464
# 358    8.15   215897
# 817    7.82    23138
# 731    7.87    28485
# 71     8.58   174878
# 726    7.87    62464
# 384    8.13    34177
# 624    7.93    85714
# 152    8.40   137636
# 614    7.94    35711
